# %%
#include parent folder
import os, sys, inspect

currentdir = os.path.dirname(
    os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

from src.domain import *

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f15eca1084ad> in <module>
#       1 domain = Domain()
# ----> 2 domain.fill(N, L, 1, 1)
#       3 domain.visualize_pos()
#
# NameError: name 'N' is not defined

# %%
# settings
rho = 0.8
N = 200
L = (float(N/rho)**(1/3))
dt = 0.005
sigma = 2
spread = 1/(3*N**(1/3))

domain = Domain()
domain.fill(N, L, spread, sigma)
domain.minimizeEnergy()

Ekin_vals = []
Epot_vals = []
for i in range(100):
    domain.verlet_advance(dt)
    Ekin_vals.append(domain.Ekin())
    Epot_vals.append(domain.Epot())

Ekin_vals = np.array(Ekin_vals)
Epot_vals = np.array(Epot_vals)

plt.plot(Ekin_vals, label="Ekin")
plt.plot(Epot_vals, label="Epot")
plt.plot(Ekin_vals+ Epot_vals, label="Etot")
plt.legend()
plt.savefig("energy.png")

# %%
spread
# Out:
# 0.05699919822255658
